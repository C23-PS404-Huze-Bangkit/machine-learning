# %% [markdown]
# ## Setup

# %%
import os
import shutil
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow_hub as hub
import numpy as np
import matplotlib.pyplot as plt
import pathlib
from absl import logging
logging.set_verbosity(logging.ERROR)

# %%
print('\u2022 Using TensorFlow Version:', tf.__version__)
print('\u2022 GPU Device Found.' if tf.config.list_physical_devices('GPU') else '\u2022 GPU Device Not Found. Running on CPU')
# Out:
# • Using TensorFlow Version: 2.7.0
# • GPU Device Found.

# %% [markdown]
# ## Read the processed data into the training dataset and validation dataset

# %%
TRAINING_DIR = "train_dir/"
VALIDATION_DIR = "validation_dir/"

# %%
def train_val_generators(TRAINING_DIR, VALIDATION_DIR):
    train_datagen = ImageDataGenerator(rescale= 1./255.,
                                        rotation_range=180,
                                        width_shift_range=0.2,
                                        height_shift_range=0.2,             
                                        shear_range=0.2,
                                        zoom_range=0.2,
                                        fill_mode='nearest',
                                        horizontal_flip=True,
                                        vertical_flip=True)
    
    train_generator = train_datagen.flow_from_directory(directory=TRAINING_DIR,
                                                        batch_size=32,
                                                        class_mode="categorical",
                                                        target_size=(229, 229))

    
    validation_datagen = ImageDataGenerator(rescale=1./255.)
    
    validation_generator = validation_datagen.flow_from_directory(directory=VALIDATION_DIR,
                                                                  batch_size=32,
                                                                  class_mode="categorical",
                                                                  target_size=(229, 229))
    
    return train_generator, validation_generator

# %%
train_generator, validation_generator = train_val_generators(TRAINING_DIR, VALIDATION_DIR)
# Out:
# Found 5600 images belonging to 20 classes.
# Found 1400 images belonging to 20 classes.

# %%
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(10,10))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img[:,:,0])
        ax.axis('off')
    plt.tight_layout()
    plt.show()

# %%
sample_training_images, _= next(train_generator)
plotImages(sample_training_images[:5])

# %% [markdown]
# ## Creating a Callback class

# %%
class cb(tf.keras.callbacks.Callback): 
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy') > 0.97 and logs.get('val_accuracy') > 0.97):
            print("\nAccuracy has reached above 97%, training stops")
            self.model.stop_training = True # training will stop when accuracy and val_accuracy have reached >= 97%

callbacks = cb()

# %% [markdown]
# ## Define, compile and Train the model

# %%
module_selection = ("inception_v3", 299, 2048) #@param ["(\"mobilenet_v2\", 224, 1280)", "(\"inception_v3\", 299, 2048)"] {type:"raw", allow-input: true}
handle_base, pixels, FV_SIZE = module_selection
MODULE_HANDLE ="https://tfhub.dev/google/tf2-preview/{}/feature_vector/4".format(handle_base)
IMAGE_SIZE = (pixels, pixels)
print("Using {} with input size {} and output dimension {}".format(MODULE_HANDLE, IMAGE_SIZE, FV_SIZE))
# Out:
# Using https://tfhub.dev/google/tf2-preview/inception_v3/feature_vector/4 with input size (299, 299) and output dimension 2048

# %%
do_fine_tuning = False #@param {type:"boolean"}

# %%
feature_extractor = hub.KerasLayer(MODULE_HANDLE,
                                   input_shape=IMAGE_SIZE + (3,), 
                                   output_shape=[FV_SIZE],
                                   trainable=do_fine_tuning)

# %%
print("Building model with", MODULE_HANDLE)

model = tf.keras.Sequential([
        feature_extractor,
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(128, activation='relu'),     
        tf.keras.layers.Dense(20,activation="softmax") 
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),loss="categorical_crossentropy", metrics=['accuracy'])
# Out:
# Building model with https://tfhub.dev/google/tf2-preview/inception_v3/feature_vector/4

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 2048)              21802784
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dense_2 (Dense)             (None, 20)                2580
#
# =================================================================
# Total params: 22,920,116
# Trainable params: 1,117,332
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
# Train the model
history = model.fit(train_generator,
                    epochs=200,
                    verbose=1,
                    validation_data=validation_generator,
                    callbacks=[callbacks]
                   )
# Out:
# Epoch 1/200
# 175/175 [==============================] - 43s 190ms/step - loss: 1.8123 - accuracy: 0.4673 - val_loss: 0.8029 - val_accuracy: 0.7500
# Epoch 2/200
# 175/175 [==============================] - 30s 171ms/step - loss: 1.1760 - accuracy: 0.6195 - val_loss: 0.6275 - val_accuracy: 0.8029
# Epoch 3/200
# 175/175 [==============================] - 30s 169ms/step - loss: 1.0908 - accuracy: 0.6463 - val_loss: 0.5996 - val_accuracy: 0.8107
# Epoch 4/200
# 175/175 [==============================] - 30s 171ms/step - loss: 1.0194 - accuracy: 0.6673 - val_loss: 0.5353 - val_accuracy: 0.8314
# Epoch 5/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.9843 - accuracy: 0.6711 - val_loss: 0.5906 - val_accuracy: 0.8114
# Epoch 6/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.9370 - accuracy: 0.6871 - val_loss: 0.5305 - val_accuracy: 0.8257
# Epoch 7/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.9414 - accuracy: 0.6882 - val_loss: 0.5124 - val_accuracy: 0.8379
# Epoch 8/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.8958 - accuracy: 0.6993 - val_loss: 0.4975 - val_accuracy: 0.8407
# Epoch 9/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.9035 - accuracy: 0.6991 - val_loss: 0.5290 - val_accuracy: 0.8150
# Epoch 10/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.8870 - accuracy: 0.7016 - val_loss: 0.5046 - val_accuracy: 0.8243
# Epoch 11/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.8563 - accuracy: 0.7116 - val_loss: 0.5018 - val_accuracy: 0.8329
# Epoch 12/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.8392 - accuracy: 0.7121 - val_loss: 0.4798 - val_accuracy: 0.8464
# Epoch 13/200
# 175/175 [==============================] - 30s 169ms/step - loss: 0.8290 - accuracy: 0.7121 - val_loss: 0.5107 - val_accuracy: 0.8407
# Epoch 14/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.8268 - accuracy: 0.7227 - val_loss: 0.4853 - val_accuracy: 0.8257
# Epoch 15/200
# 175/175 [==============================] - 30s 173ms/step - loss: 0.7901 - accuracy: 0.7321 - val_loss: 0.5057 - val_accuracy: 0.8221
# Epoch 16/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.8163 - accuracy: 0.7166 - val_loss: 0.4808 - val_accuracy: 0.8500
# Epoch 17/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.7977 - accuracy: 0.7287 - val_loss: 0.4639 - val_accuracy: 0.8507
# Epoch 18/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.7885 - accuracy: 0.7311 - val_loss: 0.4862 - val_accuracy: 0.8300
# Epoch 19/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.7638 - accuracy: 0.7366 - val_loss: 0.5053 - val_accuracy: 0.8386
# Epoch 20/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.7832 - accuracy: 0.7366 - val_loss: 0.4960 - val_accuracy: 0.8364
# Epoch 21/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.7794 - accuracy: 0.7377 - val_loss: 0.4825 - val_accuracy: 0.8293
# Epoch 22/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.7707 - accuracy: 0.7396 - val_loss: 0.4704 - val_accuracy: 0.8464
# Epoch 23/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.7351 - accuracy: 0.7486 - val_loss: 0.4560 - val_accuracy: 0.8464
# Epoch 24/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.7709 - accuracy: 0.7407 - val_loss: 0.4967 - val_accuracy: 0.8400
# Epoch 25/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.7579 - accuracy: 0.7436 - val_loss: 0.4842 - val_accuracy: 0.8436
# Epoch 26/200
# 175/175 [==============================] - 30s 174ms/step - loss: 0.7462 - accuracy: 0.7446 - val_loss: 0.4936 - val_accuracy: 0.8229
# Epoch 27/200
# 175/175 [==============================] - 30s 173ms/step - loss: 0.7242 - accuracy: 0.7570 - val_loss: 0.4961 - val_accuracy: 0.8293
# Epoch 28/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.7324 - accuracy: 0.7482 - val_loss: 0.4653 - val_accuracy: 0.8429
# Epoch 29/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.7374 - accuracy: 0.7500 - val_loss: 0.4947 - val_accuracy: 0.8357
# Epoch 30/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0
200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.4589 - accuracy: 0.8402 - val_loss: 0.4573 - val_accuracy: 0.8514
# Epoch 121/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.4344 - accuracy: 0.8427 - val_loss: 0.4471 - val_accuracy: 0.8536
# Epoch 122/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.4563 - accuracy: 0.8421 - val_loss: 0.4449 - val_accuracy: 0.8500
# Epoch 123/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.4286 - accuracy: 0.8512 - val_loss: 0.4871 - val_accuracy: 0.8357
# Epoch 124/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.4329 - accuracy: 0.8468 - val_loss: 0.4519 - val_accuracy: 0.8564
# Epoch 125/200
# 175/175 [==============================] - 29s 168ms/step - loss: 0.4225 - accuracy: 0.8486 - val_loss: 0.4438 - val_accuracy: 0.8643
# Epoch 126/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.4300 - accuracy: 0.8468 - val_loss: 0.5022 - val_accuracy: 0.8493
# Epoch 127/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.4353 - accuracy: 0.8471 - val_loss: 0.4778 - val_accuracy: 0.8493
# Epoch 128/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.4495 - accuracy: 0.8432 - val_loss: 0.4749 - val_accuracy: 0.8486
# Epoch 129/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.4360 - accuracy: 0.8466 - val_loss: 0.4619 - val_accuracy: 0.8543
# Epoch 130/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.4287 - accuracy: 0.8500 - val_loss: 0.4558 - val_accuracy: 0.8464
# Epoch 131/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.4201 - accuracy: 0.8500 - val_loss: 0.4649 - val_accuracy: 0.8457
# Epoch 132/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.4282 - accuracy: 0.8480 - val_loss: 0.4753 - val_accuracy: 0.8493
# Epoch 133/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.4020 - accuracy: 0.8605 - val_loss: 0.4888 - val_accuracy: 0.8479
# Epoch 134/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.4177 - accuracy: 0.8582 - val_loss: 0.4649 - val_accuracy: 0.8507
# Epoch 135/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.4168 - accuracy: 0.8570 - val_loss: 0.4771 - val_accuracy: 0.8514
# Epoch 136/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.4009 - accuracy: 0.8627 - val_loss: 0.4623 - val_accuracy: 0.8557
# Epoch 137/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.4140 - accuracy: 0.8532 - val_loss: 0.4695 - val_accuracy: 0.8500
# Epoch 138/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.3886 - accuracy: 0.8648 - val_loss: 0.4598 - val_accuracy: 0.8507
# Epoch 139/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.4079 - accuracy: 0.8561 - val_loss: 0.4548 - val_accuracy: 0.8571
# Epoch 140/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.4361 - accuracy: 0.8482 - val_loss: 0.4273 - val_accuracy: 0.8614
# Epoch 141/200
# 175/175 [==============================] - 29s 168ms/step - loss: 0.4027 - accuracy: 0.8575 - val_loss: 0.4679 - val_accuracy: 0.8457
# Epoch 142/200
# 175/175 [==============================] - 30s 169ms/step - loss: 0.3975 - accuracy: 0.8571 - val_loss: 0.4918 - val_accuracy: 0.8379
# Epoch 143/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.4014 - accuracy: 0.8623 - val_loss: 0.4729 - val_accuracy: 0.8507
# Epoch 144/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.4149 - accuracy: 0.8505 - val_loss: 0.4733 - val_accuracy: 0.8486
# Epoch 145/200
# 175/175 [==============================] - 30s 169ms/step - loss: 0.4076 - accuracy: 0.8541 - val_loss: 0.4853 - val_accuracy: 0.8514
# Epoch 146/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.4070 - accuracy: 0.8579 - val_loss: 0.4547 - val_accuracy: 0.8550
# Epoch 147/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.3996 - accuracy: 0.8670 - val_loss: 0.4380 - val_accuracy: 0.8521
# Epoch 148/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.4031 - accuracy: 0.8621 - val_loss: 0.5127 - val_accuracy: 0.8564
# Epoch 149/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.3997 - accuracy: 0.8593 - val_loss: 0.4807 - val_accuracy: 0.8521
# Epoch 150/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.3840 - accuracy: 0.8704 - val_loss: 0.4807 - val_accuracy: 0.8486
# Epoch 151/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.3863 - accuracy: 0.8632 - val_loss: 0.4713 - val_accuracy: 0.8521
# Epoch 152/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.4005 - accuracy: 0.8616 - val_loss: 0.4725 - val_accuracy: 0.8529
# Epoch 153/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.3857 - accuracy: 0.8661 - val_loss: 0.4874 - val_accuracy: 0.8493
# Epoch 154/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.3840 - accuracy: 0.8612 - val_loss: 0.4536 - val_accuracy: 0.8564
# Epoch 155/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.3934 - accuracy: 0.8611 - val_loss: 0.4971 - val_accuracy: 0.8471
# Epoch 156/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.3762 - accuracy: 0.8702 - val_loss: 0.4619 - val_accuracy: 0.8557
# Epoch 157/200
# 175/175 [==============================] - 29s 168ms/step - loss: 0.3832 - accuracy: 0.8655 - val_loss: 0.4793 - val_accuracy: 0.8550
# Epoch 158/200
# 175/175 [==============================] - 30s 169ms/step - loss: 0.3832 - accuracy: 0.8655 - val_loss: 0.4826 - val_accuracy: 0.8464
# Epoch 159/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.3812 - accuracy: 0.8657 - val_loss: 0.4617 - val_accuracy: 0.8571
# Epoch 160/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.3811 - accuracy: 0.8714 - val_loss: 0.4828 - val_accuracy: 0.8486
# Epoch 161/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.3584 - accuracy: 0.8791 - val_loss: 0.4878 - val_accuracy: 0.8479
# Epoch 162/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.3901 - accuracy: 0.8654 - val_loss: 0.4459 - val_accuracy: 0.8564
# Epoch 163/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.3720 - accuracy: 0.8689 - val_loss: 0.4649 - val_accuracy: 0.8571
# Epoch 164/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.3952 - accuracy: 0.8627 - val_loss: 0.4649 - val_accuracy: 0.8543
# Epoch 165/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.3722 - accuracy: 0.8745 - val_loss: 0.4831 - val_accuracy: 0.8507
# Epoch 166/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.3700 - accuracy: 0.8725 - val_loss: 0.5556 - val_accuracy: 0.8279
# Epoch 167/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.3727 - accuracy: 0.8709 - val_loss: 0.5024 - val_accuracy: 0.8507
# Epoch 168/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.3817 - accuracy: 0.8641 - val_loss: 0.4921 - val_accuracy: 0.8479
# Epoch 169/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.3699 - accuracy: 0.8702 - val_loss: 0.4687 - val_accuracy: 0.8543
# Epoch 170/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.3540 - accuracy: 0.8768 - val_loss: 0.4591 - val_accuracy: 0.8593
# Epoch 171/200
# 175/175 [==============================] - 30s 174ms/step - loss: 0.3783 - accuracy: 0.8652 - val_loss: 0.4591 - val_accuracy: 0.8557
# Epoch 172/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.3552 - accuracy: 0.8800 - val_loss: 0.5110 - val_accuracy: 0.8457
# Epoch 173/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.3671 - accuracy: 0.8714 - val_loss: 0.4583 - val_accuracy: 0.8579
# Epoch 174/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.3466 - accuracy: 0.8820 - val_loss: 0.4546 - val_accuracy: 0.8629
# Epoch 175/200
# 175/175 [==============================] - 30s 173ms/step - loss: 0.3641 - accuracy: 0.8730 - val_loss: 0.4758 - val_accuracy: 0.8579
# Epoch 176/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.3539 - accuracy: 0.8741 - val_loss: 0.5253 - val_accuracy: 0.8450
# Epoch 177/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.3476 - accuracy: 0.8789 - val_loss: 0.4951 - val_accuracy: 0.8450
# Epoch 178/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.3446 - accuracy: 0.8829 - val_loss: 0.5144 - val_accuracy: 0.8450
# Epoch 179/200
# 175/175 [==============================] - 30s 169ms/step - loss: 0.3541 - accuracy: 0.8745 - val_loss: 0.4870 - val_accuracy: 0.8486
# Epoch 180/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.3415 - accuracy: 0.8841 - val_loss: 0.4729 - val_accuracy: 0.8579
# Epoch 181/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.3432 - accuracy: 0.8771 - val_loss: 0.4810 - val_accuracy: 0.8536
# Epoch 182/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.3591 - accuracy: 0.8759 - val_loss: 0.5093 - val_accuracy: 0.8507
# Epoch 183/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.3365 - accuracy: 0.8789 - val_loss: 0.4779 - val_accuracy: 0.8521
# Epoch 184/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.3561 - accuracy: 0.8720 - val_loss: 0.5030 - val_accuracy: 0.8464
# Epoch 185/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.3340 - accuracy: 0.8838 - val_loss: 0.4966 - val_accuracy: 0.8543
# Epoch 186/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.3338 - accuracy: 0.8834 - val_loss: 0.4915 - val_accuracy: 0.8500
# Epoch 187/200
# 175/175 [==============================] - 30s 173ms/step - loss: 0.3435 - accuracy: 0.8784 - val_loss: 0.5311 - val_accuracy: 0.8579
# Epoch 188/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.3248 - accuracy: 0.8845 - val_loss: 0.5224 - val_accuracy: 0.8436
# Epoch 189/200
# 175/175 [==============================] - 29s 168ms/step - loss: 0.3582 - accuracy: 0.8748 - val_loss: 0.4773 - val_accuracy: 0.8536
# Epoch 190/200
# 175/175 [==============================] - 30s 169ms/step - loss: 0.3302 - accuracy: 0.8827 - val_loss: 0.4634 - val_accuracy: 0.8586
# Epoch 191/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.3409 - accuracy: 0.8814 - val_loss: 0.4809 - val_accuracy: 0.8529
# Epoch 192/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.3347 - accuracy: 0.8845 - val_loss: 0.4892 - val_accuracy: 0.8514
# Epoch 193/200
# 175/175 [==============================] - 30s 169ms/step - loss: 0.3368 - accuracy: 0.8836 - val_loss: 0.4694 - val_accuracy: 0.8543
# Epoch 194/200
# 175/175 [==============================] - 30s 171ms/step - loss: 0.3346 - accuracy: 0.8820 - val_loss: 0.5145 - val_accuracy: 0.8414
# Epoch 195/200
# 175/175 [==============================] - 30s 169ms/step - loss: 0.3388 - accuracy: 0.8814 - val_loss: 0.4801 - val_accuracy: 0.8571
# Epoch 196/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.3467 - accuracy: 0.8782 - val_loss: 0.4696 - val_accuracy: 0.8607
# Epoch 197/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.3321 - accuracy: 0.8825 - val_loss: 0.4647 - val_accuracy: 0.8571
# Epoch 198/200
# 175/175 [==============================] - 30s 170ms/step - loss: 0.3294 - accuracy: 0.8820 - val_loss: 0.4839 - val_accuracy: 0.8593
# Epoch 199/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.3326 - accuracy: 0.8859 - val_loss: 0.4965 - val_accuracy: 0.8457
# Epoch 200/200
# 175/175 [==============================] - 30s 172ms/step - loss: 0.3202 - accuracy: 0.8884 - val_loss: 0.4847 - val_accuracy: 0.8514

# %% [markdown]
# ### Training History

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.show()
print("")

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")
plt.show()

# %% [markdown]
# ## save model format Keras HDF5

# %%
model.save('model_Inceptionv3.h5')

# %% [markdown]
# ## Save model Exporting to TFLite

# %%
export_dir = 'saved_model/model_Inceptionv3'

tf.saved_model.save(model, export_dir)
# Out:
# INFO:tensorflow:Assets written to: saved_model/model_Inceptionv3\assets
# INFO:tensorflow:Assets written to: saved_model/model_Inceptionv3\assets

# %%
# Select mode of optimization
mode = "Speed" 

if mode == 'Storage':
    optimization = tf.lite.Optimize.OPTIMIZE_FOR_SIZE
elif mode == 'Speed':
    optimization = tf.lite.Optimize.OPTIMIZE_FOR_LATENCY
else:
    optimization = tf.lite.Optimize.DEFAULT

# %%
converter = tf.lite.TFLiteConverter.from_saved_model(export_dir)# YOUR CODE HERE

# Set the optimzations
converter.optimizations = [optimization]

# Invoke the converter to finally generate the TFLite model
tflite_model = converter.convert()

# %%
tflite_model_file = pathlib.Path('./model_Inceptionv3.tflite')
tflite_model_file.write_bytes(tflite_model)
# Out:
# 23366280
